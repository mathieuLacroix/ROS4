# %% [markdown]
# # Algorithme de séparation et évaluation

# %%
# Librairies à importer pour utiliser JuMP avec le solver SCIP
using JuMP
using SCIP

# Définition de constantes pour le statut de résolution du problème
const OPTIMAL = JuMP.MathOptInterface.OPTIMAL
const INFEASIBLE = JuMP.MathOptInterface.INFEASIBLE
const UNBOUNDED = JuMP.MathOptInterface.DUAL_INFEASIBLE;

# %% [markdown]
# Le principe de ce TP est de résoudre des PLNE en utilisant l'algorithme de séparation et évaluation. Pour déterminer une valeur relaxée à chaque noeud de l'arbre de branchements, on utilisera le package JuMP pour résoudre la relaxation linéaire.

# %% [markdown]
# **Remarque :** Ce TP se fait avant tout sur feuille (pour dessiner les arbres de branchements). La partie code consiste uniquement à résoudre des relaxations continues avec Julia/JuMP.

# %% [markdown]
# ## Exercice 1
#
# ### Question 1
#
# Résoudre le problème en nombres entiers :
#
# $\max 6 x_1 + 5 x_2 + 7 x_3 + 4 x_4 + 8 x_5$
#
# $4 x_1 + 6 x_2 + 3 x_3 + 8 x_4 + 5 x_5 \le 12$
#
# $x_1 + x_2 + 2 x_3 + x_5 \le 3$
#
# $2x_2 + x_3 + x_4 \le 2$
#
# $x_1 + 2 x_2 + x_3 + x_4 + 3 x_5 \le 4$
#
# $x_j \in \{0,1\}$ pour tout $j=1,\dots,5$
#
#
# Pour résoudre ce problème, on utilisera l'algorithme de séparation et évaluation vu en cours. On utilisera :
# * le package JuMP (modèle linéaire) pour résoudre la relaxation linéaire
# * on branchera sur la variable fractionnaire de plus petit indice
# * on effectuera un parcours en profondeur (en commençant par la gauche)
#
# Dessiner sur une feuille l'arbre de branchements obtenu (avec les valeur et solution relaxées pour chaque nœud). Combien de nœuds ont été évalués ? Est-ce moins que le nombre de points 0/1 possibles (avec les 5 variables) ?

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# **Réponse :** Écrire votre réponse ici.

# %% [markdown]
# ### Question 2
#
# Résoudre de nouveau le problème selon l'algorithme de séparation et évaluation en branchant cette fois-ci sur la variable fractionnaire de plus grand indice. Cette règle de sélection de variable est-elle plus intéressante pour cet exemple ? Dans le cas général ?

# %% [markdown]
# **Réponse :** Écrire votre réponse ici.

# %% [markdown]
# ## Exercice 2
#
# Résoudre par séparation et évaluation le PLNE suivant :
#
# $\max 6 x_1 + 12 x_2 + 3 x_3 + 8 x_4 + 9 x_5$
#
# $ x_1 + x_2 + x_5 \le 1$
#
# $x_1 + x_4 \le 1$
#
# $x_2 + x_3 \le 1$
#
# $x_3 + x_4 + x_5 \le 1$
#
# $x_i \in \{0,1\}$ pour tout $i=1,\dots,5$

# %%
############################## 
#   Saisir votre code ici.   #
##############################

# %% [markdown]
# ## Exercice 3
#
# Résoudre par séparation et évaluation le PLNE suivant :
#
# $\max 5 x_1 + 4 x_2 + 6 x_3$
#
# $x_1 + x_2 \le 1$
#
# $x_1 + x_3 \le 1$
#
# $x_2 + x_3 \le 1$
#
# $x_i \in \{0,1\}$ pour tout $i=1,\dots,3$

# %%
#=
    Écrire la relaxation linéaire ici
=#
